# %% [markdown]
# <a href="https://colab.research.google.com/github/the-fahim/CUDA-programming-for-Beginners/blob/main/NB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Dec 10 05:08:05 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# Create a simple CUDA program
# %%writefile example.cu
#include <stdio.h>

__global__ void helloCUDA() {
    printf("Hello from CUDA kernel!\n");
}

int main() {
    // Launch CUDA kernel
    helloCUDA<<<1, 1>>>();
    cudaDeviceSynchronize();
    return 0;
}
# Out:
# Writing example.cu

# %%
# %%writefile C1.cu
#
# #include <stdio.h>
#
# __global__ void hello(){
#     printf("Hello from block: %u, thread: %u\n", blockIdx.x, threadIdx.x);
# }
#
# int main(){
#     hello<<<2, 2>>>();
#     cudaDeviceSynchronize();
# }
# Out:
# Overwriting C1.cu

# %%
# Compile the CUDA program using nvcc
# !nvcc example.cu -o example
# !nvcc C1.cu -o C1


# Run the compiled program
# !./C1
# Out:
# Hello from block: 1, thread: 0
# Hello from block: 1, thread: 1
# Hello from block: 0, thread: 0
# Hello from block: 0, thread: 1
